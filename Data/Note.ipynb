# %% [markdown]
# *Récupérer nom du fichier avec le chemin*

# %%
from pathlib import Path
chemin = "./coucoucoucouc/fichier.parquet"

nom = Path(chemin).stem

print(f"DATASET : {nom}")
# Out:
# DATASET : fichier
